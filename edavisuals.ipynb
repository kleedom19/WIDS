# %% [markdown]
# # WatchDuty EDA: Evacuation Alert Delays
#
# Goal: benchmark timing from first credible signal to first protective action (evac zone activity) and surface “dangerous delay” patterns by region, source, and incident type.
#
# Primary proxy metrics:
# - First signal time: earliest `date_created` in `geo_events_external_message` per `geo_event_id`
# - First protective action time: earliest `date_created` in `evac_zone_status_geo_event_map` per `geo_event_id`
# - Delay (minutes): protective action minus first signal

# %%
import pandas as pd
import numpy as np
from pathlib import Path

DATA_DIR = Path(".")  # put your CSVs in the same folder as the notebook, or change this

FILES = {
    "ev_map": "evac_zone_status_geo_event_map.csv",
    "evac_zones": "evac_zones_gis_evaczone.csv",
    "evac_zones_changelog": "evac_zones_gis_evaczonechangelog.csv",
    "perimeters": "fire_perimeters_gis_fireperimeter.csv",
    "perimeters_changelog": "fire_perimeters_gis_fireperimeterchangelog.csv",
    "external_msgs": "geo_events_externalgeoevent.csv",
    "external_msgs_changelog": "geo_events_externalgeoeventchangelog.csv",
    "geoevents": "geo_events_geoevent.csv",
    "geoevents_changelog": "geo_events_geoeventchangelog.csv",
}

def read_csv_safely(name, nrows=None):
    path = DATA_DIR / name
    if not path.exists():
        print(f"Missing: {path}")
        return None
    return pd.read_csv(path, low_memory=False, nrows=nrows)

print("Files found:", [k for k,v in FILES.items() if (DATA_DIR / v).exists()])
# Out:
# Files found: ['ev_map', 'evac_zones', 'evac_zones_changelog', 'perimeters', 'perimeters_changelog', 'external_msgs', 'external_msgs_changelog', 'geoevents', 'geoevents_changelog']

# %%
#printing (rows, columns)  
ev_map = read_csv_safely(FILES["ev_map"])
external = read_csv_safely(FILES["external_msgs"])
geoevents = read_csv_safely(FILES["geoevents"])

(ev_map.shape, external.shape, geoevents.shape)
# Out:
# ((4429, 3), (1502495, 14), (62696, 17))

# %%
def to_dt(s):
    return pd.to_datetime(s, errors="coerce", utc=True)

ev_map["date_created"] = to_dt(ev_map["date_created"])
external["date_created"] = to_dt(external["date_created"])
geoevents["date_created"] = to_dt(geoevents["date_created"])
geoevents["date_modified"] = to_dt(geoevents.get("date_modified"))

print("ev_map range:", ev_map["date_created"].min(), "to", ev_map["date_created"].max())
print("external range:", external["date_created"].min(), "to", external["date_created"].max())
print("geoevents range:", geoevents["date_created"].min(), "to", geoevents["date_created"].max())

# uniqueness checks
print("ev_map unique uid_v2:", ev_map["uid_v2"].nunique())
print("ev_map unique geo_event_id:", ev_map["geo_event_id"].nunique())
print("external unique geo_event_id:", external["geo_event_id"].nunique())
# Out:
# ev_map range: 2023-10-25 11:28:15.254517+00:00 to 2025-09-20 22:29:54.827623+00:00
# external range: 2023-02-21 21:34:31.052942+00:00 to 2025-09-05 20:35:26.465983+00:00
# geoevents range: 2021-08-11 00:09:56.481066+00:00 to 2025-09-05 20:25:28.007096+00:00
# ev_map unique uid_v2: 3909
# ev_map unique geo_event_id: 483
# external unique geo_event_id: 41906

# %%
first_signal = (
    external.dropna(subset=["geo_event_id", "date_created"])
    .groupby("geo_event_id", as_index=False)["date_created"]
    .min()
    .rename(columns={"date_created": "first_signal_time"})
)

first_action = (
    ev_map.dropna(subset=["geo_event_id", "date_created"])
    .groupby("geo_event_id", as_index=False)["date_created"]
    .min()
    .rename(columns={"date_created": "first_action_time"})
)

delays = first_signal.merge(first_action, on="geo_event_id", how="left")
delays["mins_signal_to_action"] = (
    (delays["first_action_time"] - delays["first_signal_time"]).dt.total_seconds() / 60.0
)

delays.describe(include="all")
# Out:
#        geo_event_id                    first_signal_time  \
# count  41906.000000                                41906
# mean   32298.550685  2024-08-27 09:36:14.215993856+00:00
# min      179.000000     2023-04-28 22:12:22.767797+00:00
# 25%    16579.250000  2024-02-27 21:59:40.964591360+00:00
# 50%    32576.500000  2024-08-29 19:06:04.453777408+00:00
# 75%    46744.750000  2025-04-22 22:33:16.376892416+00:00
# max    62822.000000     2025-09-05 20:16:43.241686+00:00
# std    17799.624240                                  NaN
#
#                          first_action_time  mins_signal_to_action
# count                                  108             108.000000
# mean   2025-04-10 15:50:42.317532672+00:00            2697.107601
# min       2024-06-25 20:50:53.404446+00:00            -570.402931
# 25%    2024-09-06 11:46:41.976812800+00:00              70.887725
# 50%    2025-07-14 02:35:28.833531904+00:00             211.488664
# 75%    2025-08-23 01:01:51.767871488+00:00            2228.183869
# max       2025-09-11 00:04:48.611875+00:00           34654.248365
# std                                    NaN            5847.959622

# %%
delays2 = delays.merge(
    geoevents[["id", "name", "geo_event_type", "notification_type", "external_source", "is_active", "is_visible"]],
    left_on="geo_event_id",
    right_on="id",
    how="left",
).drop(columns=["id"])

# Define “dangerous delay” threshold (tune this)
THRESH_MIN = 60  # 60 minutes as a starting point
delays2["dangerous_delay"] = delays2["mins_signal_to_action"].ge(THRESH_MIN)

# Top delayed incidents
delays2.sort_values("mins_signal_to_action", ascending=False).head(25)
# Out:
#        geo_event_id                first_signal_time  \
# 37612       57385.0 2025-07-28 18:45:17.244457+00:00
# 16465       26342.0 2024-07-17 02:41:36.766166+00:00
# 16693       26643.0 2024-07-18 17:55:33.791581+00:00
# 40843       61614.0 2025-08-26 01:28:15.553805+00:00
# 16552       26458.0 2024-07-17 21:50:46.150833+00:00
# 16501       26392.0 2024-07-17 17:35:39.903290+00:00
# 16188       25865.0 2024-07-14 00:30:42.820710+00:00
# 22655       35116.0 2024-09-28 21:30:56.402600+00:00
# 36350       55331.0 2025-07-10 18:23:01.272446+00:00
# 32807       48507.0 2025-05-13 17:50:06.711036+00:00
# 34200       51304.0 2025-06-12 14:53:04.944572+00:00
# 15864       25339.0 2024-07-10 16:25:50.415096+00:00
# 16550       26456.0 2024-07-17 22:31:36.766465+00:00
# 16585       26505.0 2024-07-17 23:02:39.523630+00:00
# 16556       26464.0 2024-07-17 23:05:17.167663+00:00
# 38354       58374.0 2025-08-02 18:53:15.098838+00:00
# 38423       58471.0 2025-08-02 23:03:26.894068+00:00
# 16738       26700.0 2024-07-18 22:14:39.563845+00:00
# 36583       55714.0 2025-07-14 02:23:39.005492+00:00
# 41866                        Black Rock Fire (963)       wildfire
#
#       notification_type external_source  is_active  is_visible  \
# 37612            normal         wildcad        1.0         1.0
# 16465            normal         wildcad        0.0         0.0
# 16693            normal         wildcad        0.0         0.0
# 40843            normal            nifc        1.0         1.0
# 16552            normal         wildcad        0.0         0.0
# 16501            normal         wildcad        0.0         0.0
# 16188            normal            nifc        0.0         0.0
# 22655            normal         wildcad        0.0         0.0
# 36350            normal         wildcad        0.0         0.0
# 32807            normal         wildcad        0.0         0.0
# 34200            normal            nifc        0.0         0.0
# 15864            normal            nifc        0.0         0.0
# 16550            normal         wildcad        0.0         0.0
# 16585            normal         wildcad        0.0         0.0
# 16556            normal            nifc        0.0         0.0
# 38354            normal         wildcad        0.0         0.0
# 38423            normal         wildcad        1.0         1.0
# 16738            normal         wildcad        0.0         0.0
# 36583            normal            nifc        0.0         0.0
# 41768            normal             NaN        1.0         1.0
# 21138            normal         wildcad        0.0         0.0
# 36321            normal         wildcad        1.0         1.0
# 17142            normal         wildcad        0.0         0.0
# 35005            normal            nifc        0.0         0.0
# 41866            normal         wildcad        1.0         1.0
#
#        dangerous_delay
# 37612             True
# 16465             True
# 16693             True
# 40843             True
# 16552             True
# 16501             True
# 16188             True
# 22655             True
# 36350             True
# 32807             True
# 34200             True
# 15864             True
# 16550             True
# 16585             True
# 16556             True
# 38354             True
# 38423             True
# 16738             True
# 36583             True
# 41768             True
# 21138             True
# 36321             True
# 17142             True
# 35005             True
# 41866             True

# %%
summary_by_source = (
    delays2.groupby(["external_source", "geo_event_type"], dropna=False)
    .agg(
        incidents=("geo_event_id", "nunique"),
        pct_missing_action=("first_action_time", lambda x: x.isna().mean()),
        median_mins=("mins_signal_to_action", "median"),
        p90_mins=("mins_signal_to_action", lambda s: np.nanpercentile(s.dropna(), 90) if s.notna().any() else np.nan),
    )
    .reset_index()
    .sort_values(["pct_missing_action", "p90_mins"], ascending=False)
)

summary_by_source.head(30)
# Out:
#   external_source geo_event_type  incidents  pct_missing_action  median_mins  \
# 0            adeq       wildfire         86            1.000000          NaN
# 1             dnr       wildfire        163            1.000000          NaN
# 3             odf       wildfire        700            1.000000          NaN
# 4           pfirs       wildfire       2713            1.000000          NaN
# 5      pulsepoint       wildfire          1            1.000000          NaN
# 6        texas_am       wildfire        157            1.000000          NaN
# 9             NaN            NaN          1            1.000000          NaN
# 2            nifc       wildfire      14321            0.997975  1127.512987
# 7         wildcad       wildfire      22988            0.997825   620.929991
# 8             NaN       wildfire        776            0.962629    72.357276
#
#        p90_mins
# 0           NaN
# 1           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 9           NaN
# 2   5984.501505
# 7  11819.187609
# 8    793.638585

# %%
danger_candidates = delays2[
    delays2["first_signal_time"].notna() &
    (delays2["first_action_time"].isna() | (delays2["mins_signal_to_action"] >= THRESH_MIN))
].copy()

danger_candidates = danger_candidates.sort_values(
    ["first_action_time", "mins_signal_to_action"],
    ascending=[True, False]
)

danger_candidates.head(50)
# Out:
#        geo_event_id                first_signal_time  \
#
#                                               name geo_event_type  \
# 15864                                   Falls Fire       wildfire
# 16529                          Round Mountain Fire       wildfire
# 16528                                 Wickiup Fire       wildfire
# 16817                                Jackpine Fire       wildfire
# 16550                              Pilot Rock Fire       wildfire
# 16556                        North Fork Owens Fire       wildfire
# 16585                                   Snake Fire       wildfire
# 16188                               Lone Rock Fire       wildfire
# 16738  Monkey Creek Fire (Battle Mountain Complex)       wildfire
# 17155                               Telephone Fire       wildfire
# 17142                       Crazy Creek Fire (501)       wildfire
# 16501                                     Red Fire       wildfire
# 16552                Lemolo Fire (Diamond Complex)       wildfire
# 16465                 Trail Fire (Diamond Complex)       wildfire
# 16693                             Double Snag Fire       wildfire
# 19064                                    Farm Fire       wildfire
# 20045                            Ochoco Fire (675)       wildfire
# 21116                             Copperfield Fire       wildfire
# 21139                          Shoe Fly Fire (766)       wildfire
# 21223                                     779 Fire       wildfire
# 21182                        Rail Ridge Fire (761)       wildfire
# 21138                        Wiley Flat Fire (772)       wildfire
# 21458                         Studhorse Fire (827)       wildfire
# 21499                             Devils Knob Fire       wildfire
# 21599        Backside Fire (Bachelor Complex, 868)       wildfire
# 21565                Service Fire (Fossil Complex)       wildfire
# 21596                              Buck Creek Fire       wildfire
# 21573                                Flat Top Fire       wildfire
# 22655                             Yellow Lake Fire       wildfire
# 23054                             Pine Fire (1002)       wildfire
# 32739                             Munger Shaw Fire       wildfire
# 32807                                   Greer Fire       wildfire
# 33629                               Telephone Fire       wildfire
# 34103                                   Aspen Fire       wildfire
# 34166                              Strawberry Fire       wildfire
# 34422                     Alder Springs Fire (291)       wildfire
# 34200                                   Trout Fire       wildfire
# 34558                              Red Canyon Fire       wildfire
# 35011                                   Polar Fire       wildfire
# 35005                               Oak Ridge Fire       wildfire
# 35183                                 Monarch Fire       wildfire
# 36253                           Willow Fire (0523)       wildfire
# 36243                              Long Point Fire       wildfire
# 36321                               South Rim Fire       wildfire
# 36567                              Cram Fire (545)       wildfire
# 36583                                  Ute 63 Fire       wildfire
# 36350                            Turner Gulch Fire       wildfire
# 36927                                Coreless Fire       wildfire
# 37433                                Rim Road Fire       wildfire
# 37795                              Rock Creek Fire       wildfire
#
#       notification_type external_source  is_active  is_visible  \
# 15864            normal            nifc        0.0         0.0
# 16529            normal            nifc        0.0         0.0
# 16528            normal            nifc        0.0         0.0
# 16817            normal            nifc        0.0         0.0
# 16550            normal         wildcad        0.0         0.0
# 16556            normal            nifc        0.0         0.0
# 16585            normal         wildcad        0.0         0.0
# 16188            normal            nifc        0.0         0.0
# 16738            normal         wildcad        0.0         0.0
# 17155            normal            nifc        0.0         0.0
# 17142            normal         wildcad        0.0         0.0
# 16501            normal         wildcad        0.0         0.0
# 16552            normal         wildcad        0.0         0.0
# 16465            normal         wildcad        0.0         0.0
# 16693            normal         wildcad        0.0         0.0
# 19064            normal         wildcad        0.0         0.0
# 20045            normal         wildcad        0.0         0.0
# 21116            normal         wildcad        0.0         0.0
# 21139            normal         wildcad        0.0         0.0
# 21223            normal         wildcad        0.0         0.0
# 21182            normal            nifc        0.0         0.0
# 21138            normal         wildcad        0.0         0.0
# 21458            normal         wildcad        0.0         0.0
# 21499            normal            nifc        0.0         0.0
# 21599            normal            nifc        0.0         0.0
# 21565            normal         wildcad        0.0         0.0
# 21596            normal            nifc        0.0         0.0
# 21573            normal            nifc        0.0         0.0
# 22655            normal         wildcad        0.0         0.0
# 23054            normal         wildcad        0.0         0.0
# 32739            normal         wildcad        0.0         0.0
# 32807            normal         wildcad        0.0         0.0
# 33629            normal         wildcad        0.0         0.0
# 34103            normal         wildcad        0.0         0.0
# 34166            normal         wildcad        0.0         0.0
# 34422            normal         wildcad        0.0         0.0
# 34200            normal            nifc        0.0         0.0
# 34558            normal         wildcad        0.0         0.0
# 35011            normal         wildcad        0.0         0.0
# 35005            normal            nifc        0.0         0.0
# 35183            normal         wildcad        0.0         0.0
# 36253            normal         wildcad        0.0         0.0
# 36243            normal            nifc        0.0         0.0
# 36321            normal         wildcad        1.0         1.0
# 36567            normal            nifc        0.0         0.0
# 36583            normal            nifc        0.0         0.0
# 36350            normal         wildcad        0.0         0.0
# 36927            normal            nifc        0.0         0.0
# 37433            normal         wildcad        0.0         0.0
# 37795            normal            nifc        0.0         0.0
#
#        dangerous_delay
# 15864             True
# 16529             True
# 16528             True
# 16817             True
# 16550             True
# 16556             True
# 16585             True
# 16188             True
# 16738             True
# 17155             True
# 17142             True
# 16501             True
# 16552             True
# 16465             True
# 16693             True
# 19064             True
# 20045             True
# 21116             True
# 21139             True
# 21223             True
# 21182             True
# 21138             True
# 21458             True
# 21499             True
# 21599             True
# 21565             True
# 21596             True
# 21573             True
# 22655             True
# 23054             True
# 32739             True
# 32807             True
# 33629             True
# 34103             True
# 34166             True
# 34422             True
# 34200             True
# 34558             True
# 35011             True
# 35005             True
# 35183             True
# 36253             True
# 36243             True
# 36321             True
# 36567             True
# 36583             True
# 36350             True
# 36927             True
# 37433             True
# 37795             True

# %%
evac_zones = read_csv_safely(FILES["evac_zones"], nrows=None)
evac_zones_ch = read_csv_safely(FILES["evac_zones_changelog"], nrows=None)

evac_zones["date_created"] = to_dt(evac_zones["date_created"])
evac_zones["date_modified"] = to_dt(evac_zones["date_modified"])
evac_zones_ch["date_created"] = to_dt(evac_zones_ch["date_created"])

evac_zones[["is_active", "status", "external_status"]].value_counts(dropna=False).head(20)
# Out:
# is_active  status      external_status
# True       NaN         Normal                          30236
# False      NaN         NaN                              3872
# True       NaN         NaN                               866
#                        No Order or Warning               565
#                        No Evacuation Order               559
#                        Lifted                            370
#                        INACTIVE                          327
#                        0                                 270
#                        Liftd                              98
#                        NO EVACUATION                      85
#            warnings    Evacuation Warning                 35
#            orders      Evacuation Order                   16
#            advisories  Monitor                            13
#                        Ready                              13
#            NaN         00                                 12
#            advisories  Evacuation Level 1: Be Ready       11
#            warnings    Warn                               11
#            NaN         No Status                          11
#            orders      Order                              10
#            NaN         Order Lifted                        9
# Name: count, dtype: int64
